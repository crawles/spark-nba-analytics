# %%
import pandas as pd
import os

# %% [markdown]
# # From NBA Savant

# %%
def read_csv_dir(dirname):
    dfs = []
    for f in os.listdir(dirname):
        df = pd.read_csv(os.path.join(dirname,f))
        dfs.append(df)
    return pd.concat(dfs)

_dfs = []
for yr in range(2011,(2016+1)):
    dirname = 'data/shot_charts_top_10/{yr}'.format(yr = yr)
    df = read_csv_dir(dirname)
    print yr,df.name.value_counts()
    df.insert(0, 'yr', yr)
    _dfs.append(df)
shot_df = pd.concat(_dfs, ignore_index = True)
# Out:
# 2011 Kobe Bryant          1639
# Monta Ellis          1611
# Derrick Rose         1597
# Kevin Durant         1538
# Carmelo Anthony      1503
# LeBron James         1485
# Amare Stoudemire     1482
# LaMarcus Aldridge    1415
# Dwyane Wade          1383
# Blake Griffin        1376
# Name: name, dtype: int64
# 2012 Kobe Bryant          1336
# Kevin Durant         1297
# Russell Westbrook    1266
# LeBron James         1169
# Josh Smith           1101
# Rudy Gay             1067
# Kevin Love           1059
# Al Jefferson         1048
# Dirk Nowitzki        1034
# Blake Griffin        1022
# Name: name, dtype: int64
# 2013 Kobe Bryant          1593
# Russell Westbrook    1534
# Carmelo Anthony      1489
# Monta Ellis          1436
# Kevin Durant         1433
# Stephen Curry        1388
# LeBron James         1354
# LaMarcus Aldridge    1318
# Al Jefferson         1236
# David Lee            1160
# Name: name, dtype: int64
# 2014 Kevin Durant         1688
# Carmelo Anthony      1643
# LaMarcus Aldridge    1423
# Kevin Love           1421
# DeMar DeRozan        1407
# Stephen Curry        1383
# Al Jefferson         1376
# Blake Griffin        1359
# LeBron James         1353
# Dirk Nowitzki        1273
# Name: name, dtype: int64
# 2015 Russell Westbrook    1471
# James Harden         1470
# LaMarcus Aldridge    1415
# Damian Lillard       1360
# Monta Ellis          1354
# Stephen Curry        1341
# Klay Thompson        1299
# LeBron James         1279
# Nikola Vucevic       1206
# Anthony Davis        1199
# Name: name, dtype: int64
# 2016 James Harden         1599
# Stephen Curry        1569
# Damian Lillard       1437
# Russell Westbrook    1407
# CJ McCollum          1407
# DeMar DeRozan        1376
# Klay Thompson        1371
# Kevin Durant         1345
# LeBron James         1339
# KarlAnthony Towns    1133
# Name: name, dtype: int64

# %%
shot_df.name.value_counts()
# Out:
# LeBron James         7979
# Kevin Durant         7301
# Stephen Curry        5681
# Russell Westbrook    5678
# LaMarcus Aldridge    5571
# Carmelo Anthony      4635
# Kobe Bryant          4568
# Monta Ellis          4401
# Blake Griffin        3757
# Al Jefferson         3660
# James Harden         3069
# Damian Lillard       2797
# DeMar DeRozan        2783
# Klay Thompson        2670
# Kevin Love           2480
# Dirk Nowitzki        2307
# Derrick Rose         1597
# Amare Stoudemire     1482
# CJ McCollum          1407
# Dwyane Wade          1383
# Nikola Vucevic       1206
# Anthony Davis        1199
# David Lee            1160
# KarlAnthony Towns    1133
# Josh Smith           1101
# Rudy Gay             1067
# Name: name, dtype: int64

# %%
james_harden = shot_df.query('name == "James Harden" and yr == 2015')

# %%
sns.jointplot(shot_df.x,shot_df.y,kind = 'hex', stat_func=None)

# %%
# get our colormap for the main kde plot
# Note we can extract a color from cmap to use for 
# the plots that lie on the side and top axes
cmap=plt.cm.YlOrRd_r 

# n_levels sets the number of contour lines for the main kde plot
joint_shot_chart = sns.jointplot(james_harden.x, james_harden.y, stat_func=None,
                                 kind='kde', space=0, color=cmap(0.1),
                                 cmap=cmap, n_levels=50)

# %%
plt.plot(df.x,df.y,'bo')

# %%
df.shape
# Out:
# (559, 23)

# %%
cmap=plt.cm.gist_heat_r
joint_shot_chart = sns.jointplot(df.x, df.y, stat_func=None,
                                 kind='hex', space=0, color=cmap(.2), cmap=cmap, size = 10)
joint_shot_chart.fig.set_size_inches(12,11)
# A joint plot has 3 Axes, the first one called ax_joint 
# is the one we want to draw our court onto 
ax = joint_shot_chart.ax_joint
# draw_court(ax)

# Adjust the axis limits and orientation of the plot in order
# to plot half court, with the hoop by the top of the plot
ax.set_xlim(-250,250)
ax.set_ylim(422.5, -47.5)

# Get rid of axis labels and tick marks
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(labelbottom='off', labelleft='off')

# %%
plt.hist(df.shot_distance)
# Out:
# (array([ 906.,  264.,  210.,  343.,   28.,    2.,    2.,    1.,    0.,    2.]),
#  array([  0. ,   6.8,  13.6,  20.4,  27.2,  34. ,  40.8,  47.6,  54.4,
#          61.2,  68. ]),
#  <a list of 10 Patch objects>)

# %%
df = shot_df.query('name == "Stephen Curry"')
plt.hexbin(df.x, df.y,gridsize=20,cmap=plt.cm.YlOrRd_r)

# %%
plt.plot(df.x, df.y, 'bo')

# %%
from matplotlib.offsetbox import  OffsetImage

# create our jointplot

# get our colormap for the main kde plot
# Note we can extract a color from cmap to use for 
# the plots that lie on the side and top axes
cmap=plt.cm.YlOrRd_r 

# n_levels sets the number of contour lines for the main kde plot
joint_shot_chart = sns.jointplot(shot_df.x, shot_df.y, stat_func=None,
                                 kind='hex', space=0, color=cmap(.2), cmap=cmap)

# %%
# sns.jointplot(shot_df.x,shot_df.y, kind = 'hex', )
plt.hexbin(james_harden.x,james_harden.y)

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'player', u'pos', u'age', u'team_id', u'g', u'gs',
#        u'mp', u'fg', u'fga', u'fg_pct', u'fg3', u'fg3a', u'fg3_pct', u'fg2',
#        u'fg2a', u'fg2_pct', u'efg_pct', u'ft', u'fta', u'ft_pct', u'orb',
#        u'drb', u'trb', u'ast', u'stl', u'blk', u'tov', u'pf', u'pts', u'yr'],
#       dtype='object')
